# %% [markdown]
# # Ibis Flink Backend Demo
# ## Project Scope
# Build ML features using ibis Flink for credit card transaction level fraud detection.
# This featusre will be used to build a binary classification model for transaction fraud detection.
# ## Data Description
# This is a simulated credit card transaction dataset containing legitimate and fraud transactions from the duration 1st Jan 2019 - 31st Dec 2020. It covers credit cards of 1000 customers doing transactions with a pool of 800 merchants.
#
# ### Schema
# ```
# trans_date_trans_time: str, MM/DD/YY HH:MM:SS format
# cc_num: int
# merchant: str, Name of merchant. Prepended with “fraud_” for some reason
# category: str, Purchase category, e.g. entertainment, kids_pets, home, food_dining, etc.
# amt: float, Transaction amount
# first: str, firt name
# last: str, last name
# gender: str, (M/F)
# street: str,
# city: str,
# state: str, Two-letter representation of US state
# zip: int, 4-5 digit zip code
# lat: float
# long: float
# city_pop: int, Population of city of buyer
# job: str
# Job of buyer
# dob: str, DD/MM/YY format
# trans_num: str, MD5 hash
# unix_time: int, Event timestamp
# merch_lat: float
# merch_long: float
# is_fraud: int, Event label
# ```
# ## Mocked Kafka
# To ingest the dataset, we upload the dataset to a blob storage (aws S3) and read object into Kafka.
#
# ## Features
# While this is not an exhaustive feature list, we aim to showcase how to leverage Ibis Flink for feature engineering. Below are some sample features, and feel free to explore additional ideas:
# - Transaction level features
#     - Amt
#     - Month of the year of this transaction
#     - Day of week
#     - Hour of the day
# - Credit card level features
#     - cc_num_{total, max, min, median}_amt_in_last_x(min, hour, day)
# - User (use first name, last name, and dob as user identifier) level features
#     - cc_num_{total, max, min, median}_amt_in_last_x(min, hour, day)
#     - user age
# - {merchant, category, and region (zipcode here)} level features
#     - {merchant, category, and region}_{total, max, min, median}_amt_in_last_x(min, hour, day)
#
#
# ## Ibis Flink Transformation

# %%
import sys

import ibis
import ibis.expr.datatypes as dt
import ibis.expr.schema as sch
from kafka import KafkaConsumer
from pyflink.table import EnvironmentSettings, TableEnvironment
import pandas as pd
import json
import datetime
import StringIO
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 11
#       9 import json
#      10 import datetime
# ---> 11 import StringIO
#
# ModuleNotFoundError: No module named 'StringIO'

# %%
## 0. Confirm data is successfully ingested
consumer = KafkaConsumer("transaction", auto_offset_reset='earliest')
for msg in zip(range(10), consumer):
    print(msg)
# Out:
# (0, ConsumerRecord(topic='transaction', partition=0, offset=0, timestamp=1702427230080, timestamp_type=0, key=None, value=b'{"trans_date_trans_time": "01/01/19 00:00:13", "cc_num": 2703190000000000, "merchant": "fraud_Rippin, Kub and Mann", "category": "misc_net", "amt": 4.97, "first": "Jennifer", "last": "Banks", "gender": "F", "street": "561 Perry Cove", "city": "Moravian Falls", "state": "NC", "zipcode": "28654", "latitude": 36.0788, "longitude": -81.1781, "city_pop": 3495, "job": "Psychologist, counselling", "dob": "3/9/88", "trans_num": "0b242abb623afc578575680df30655b9", "unix_time": 1325376018000, "merch_lat": 36.011293, "merch_long": -82.048315, "is_fraud": 0, "trans_id": 0}', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=567, serialized_header_size=-1))
# (1, ConsumerRecord(topic='transaction', partition=0, offset=1, timestamp=1702427230080, timestamp_type=0, key=None, value=b'{"trans_date_trans_time": "01/01/19 00:00:16", "cc_num": 630423000000, "merchant": "fraud_Heller, Gutmann and Zieme", "category": "grocery_pos", "amt": 107.23, "first": "Stephanie", "last": "Gill", "gender": "F", "street": "43039 Riley Greens Suite 393", "city": "Orient", "state": "WA", "zipcode": "99160", "latitude": 48.8878, "longitude": -118.2105, "city_pop": 149, "job": "Special educational needs teacher", "dob": "6/21/78", "trans_num": "1f76529f8574734946361c461b024d99", "unix_time": 1325376044000, "merch_lat": 49.159047, "merch_long": -118.186462, "is_fraud": 0, "trans_id": 1}', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=589, serialized_header_size=-1))
# (2, ConsumerRecord(topic='transaction', partition=0, offset=2, timestamp=1702427230080, timestamp_type=0, key=None, value=b'{"trans_date_trans_time": "01/01/19 00:00:12", "cc_num": 38859500000000, "merchant": "fraud_Lind-Buckridge", "category": "entertainment", "amt": 220.11, "first": "Edward", "last": "Sanchez", "gender": "M", "street": "594 White Dale Suite 530", "city": "Malad City", "state": "ID", "zipcode": "83252", "latitude": 42.1808, "longitude": -112.262, "city_pop": 4154, "job": "Nature conservation officer", "dob": "1/19/62", "trans_num": "a1a22d70485983eac12b5b88dad1cf95", "unix_time": 1325376051000, "merch_lat": 43.150704, "merch_long": -112.154481, "is_fraud": 0, "trans_id": 2}', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=576, serialized_header_size=-1))
# (3, ConsumerRecord(topic='transaction', partition=0, offset=3, timestamp=1702427230080, timestamp_type=0, key=None, value=b'{"trans_date_trans_time": "01/01/19 00:01:14", "cc_num": 3534090000000000, "merchant": "fraud_Kutch, Hermiston and Farrell", "category": "gas_transport", "amt": 45.0, "first": "Jeremy", "last": "White", "gender": "M", "street": "9443 Cynthia Court Apt. 038", "city": "Boulder", "state": "MT", "zipcode": "59632", "latitude": 46.2306, "longitude": -112.1138, "city_pop": 1939, "job": "Patent attorney", "dob": "1/12/67", "trans_num": "6b849c168bdad6f867558c3793159a81", "unix_time": 1325376076000, "merch_lat": 47.034331, "merch_long": -112.561071, "is_fraud": 0, "trans_id": 3}', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=577, serialized_header_size=-1))
# (4, ConsumerRecord(topic='transaction', partition=0, offset=4, timestamp=1702427230080, timestamp_type=0, key=None, value=b'{"trans_date_trans_time": "01/01/19 00:03:34", "cc_num": 375534000000000, "merchant": "fraud_Keeling-Crist", "category": "misc_pos", "amt": 41.96, "first": "Tyler", "last": "Garcia", "gender": "M", "street": "408 Bradley Rest", "city": "Doe Hill", "state": "VA", "zipcode": "24433", "latitude": 38.4207, "longitude": -79.4629, "city_pop": 99, "job": "Dance movement psychotherapist", "dob": "3/28/86", "trans_num": "a41d7549acf90789359a9aa5346dcb46", "unix_time": 1325376186000, "merch_lat": 38.674999, "merch_long": -78.632459, "is_fraud": 0, "trans_id": 4}', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=558, serialized_header_size=-1))
# (5, ConsumerRecord(topic='transaction', partition=0, offset=5, timestamp=1702427230080, timestamp_type=0, key=None, value=b'{"trans_date_trans_time": "01/01/19 00:04:23", "cc_num": 4767270000000000, "merchant": "fraud_Stroman, Hudson and Erdman", "category": "gas_transport", "amt": 94.63, "first": "Jennifer", "last": "Conner", "gender": "F", "street": "4655 David Island", "city": "Dublin", "state": "PA", "zipcode": "18917", "latitude": 40.375, "longitude": -75.2045, "city_pop": 2158, "job": "Transport planner", "dob": "6/19/61", "trans_num": "189a841a0a8ba03058526bcfe566aab5", "unix_time": 1325376248000, "merch_lat": 40.653382, "merch_long": -76.152667, "is_fraud": 0, "trans_id": 5}', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=567, serialized_header_size=-1))
# (6, ConsumerRecord(topic='transaction', partition=0, offset=6, timestamp=1702427230080, timestamp_type=0, key=None, value=b'{"trans_date_trans_time": "01/01/19 00:04:18", "cc_num": 30074700000000, "merchant": "fraud_Rowe-Vandervort", "category": "grocery_net", "amt": 44.54, "first": "Kelsey", "last": "Richards", "gender": "F", "street": "889 Sarah Station Suite 624", "city": "Holcomb", "state": "KS", "zipcode": "67851", "latitude": 37.9931, "longitude": -100.9893, "city_pop": 2691, "job": "Arboriculturist", "dob": "8/16/93", "trans_num": "83ec1cc84142af6e2acf10c44949e720", "unix_time": 1325376282000, "merch_lat": 37.162705, "merch_long": -100.15337, "is_fraud": 0, "trans_id": 6}', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=563, serialized_header_size=-1))
# (7, ConsumerRecord(topic='transaction', partition=0, offset=7, timestamp=1702427230080, timestamp_type=0, key=None, value=b'{"trans_date_trans_time": "01/01/19 00:05:02", "cc_num": 6011360000000000, "merchant": "fraud_Corwin-Collins", "category": "gas_transport", "amt": 71.65, "first": "Steven", "last": "Williams", "gender": "M", "street": "231 Flores Pass Suite 720", "city": "Edinburg", "state": "VA", "zipcode": "22824", "latitude": 38.8432, "longitude": -78.6003, "city_pop": 6018, "job": "Designer, multimedia", "dob": "8/21/47", "trans_num": "6d294ed2cc447d2c71c7171a3d54967c", "unix_time": 1325376308000, "merch_lat": 38.948089, "merch_long": -78.540296, "is_fraud": 0, "trans_id": 7}', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=569, serialized_header_size=-1))
# (8, ConsumerRecord(topic='transaction', partition=0, offset=8, timestamp=1702427230080, timestamp_type=0, key=None, value=b'{"trans_date_trans_time": "01/01/19 00:05:22", "cc_num": 4922710000000000, "merchant": "fraud_Herzog Ltd", "category": "misc_pos", "amt": 4.27, "first": "Heather", "last": "Chase", "gender": "F", "street": "6888 Hicks Stream Suite 954", "city": "Manor", "state": "PA", "zipcode": "15665", "latitude": 40.3359, "longitude": -79.6607, "city_pop": 1472, "job": "Public affairs consultant", "dob": "3/7/41", "trans_num": "fc28024ce480f8ef21a32d64c93a29f5", "unix_time": 1325376318000, "merch_lat": 40.351813, "merch_long": -79.958146, "is_fraud": 0, "trans_id": 8}', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=560, serialized_header_size=-1))
# (9, ConsumerRecord(topic='transaction', partition=0, offset=9, timestamp=1702427230080, timestamp_type=0, key=None, value=b'{"trans_date_trans_time": "01/01/19 00:06:07", "cc_num": 2720830000000000, "merchant": "fraud_Schoen, Kuphal and Nitzsche", "category": "grocery_pos", "amt": 198.39, "first": "Melissa", "last": "Aguilar", "gender": "F", "street": "21326 Taylor Squares Suite 708", "city": "Clarksville", "state": "TN", "zipcode": "37040", "latitude": 36.522, "longitude": -87.349, "city_pop": 151785, "job": "Pathologist", "dob": "3/28/74", "trans_num": "3b9014ea8fb80bd65de0b1463b00b00e", "unix_time": 1325376361000, "merch_lat": 37.179198, "merch_long": -87.485381, "is_fraud": 0, "trans_id": 9}', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=580, serialized_header_size=-1))

# %%
import boto3

s3 = boto3.client(
        "s3",
        aws_access_key_id="AKIA2ISCTSRODXIETT6O",
        aws_secret_access_key="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",
    )
    # Download the CSV file from S3
response = s3.get_object(Bucket="claypot-fraud-detection", Key="FraudTransactions.csv")
csv_data = response['Body'].read().decode('utf-8')

# %%
csv_file = StringIO(csv_data)
df = pd.read_csv(csv_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 csv_file = StringIO(csv_data)
#       2 df = pd.read_csv(csv_file)
#
# NameError: name 'StringIO' is not defined

# %%
num_events = 5000
batch_size = 32
rows = []

for i, msg in zip(range(num_events), consumer):
    if i % 1000 == 0: print(i)
    rows.append(msg)

df = pd.DataFrame([json.loads(row.value) for row in rows])
df['trans_date_trans_time'] = pd.to_datetime(df['trans_date_trans_time'], format='%m/%d/%y %H:%M:%S')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[89], line 5
#       2 batch_size = 32
#       3 rows = []
# ----> 5 for i, msg in zip(range(num_events), consumer):
#       6     if i % 1000 == 0: print(i)
#       7     rows.append(msg)
#
# File ~/.local/lib/python3.10/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~/.local/lib/python3.10/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~/.local/lib/python3.10/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~/.local/lib/python3.10/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~/.local/lib/python3.10/site-packages/kafka/consumer/group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File ~/.local/lib/python3.10/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~/.local/lib/python3.10/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File ~/.python/current/lib/python3.10/selectors.py:469, in EpollSelector.select(self, timeout)
#     467 ready = []
#     468 try:
# --> 469     fd_event_list = self._selector.poll(timeout, max_ev)
#     470 except InterruptedError:
#     471     return ready
#
# KeyboardInterrupt:

# %%
df.head(2)
# Out:
#   trans_date_trans_time         cc_num                               merchant  \
# 0   2019-01-02 20:54:35  4681700000000  fraud_Hodkiewicz, Prohaska and Paucek
# 1   2019-01-02 20:55:51  4755700000000    fraud_Walter, Hettinger and Kessler
#
#         category   amt   first      last gender  \
# 0         travel  2.47  Joseph  Gonzalez      M
# 1  personal_care  3.48  Robert     Evans      M
#
#                           street          city  ... longitude city_pop  \
# 0       319 Wendy Fort Suite 179  Murfreesboro  ...  -86.4210   158701
# 1  01892 Patricia Vista Apt. 828        Sachse  ...  -96.6012    20328
#
#                      job        dob                         trans_num  \
# 0  Journalist, newspaper 1978-03-06  70740d97da9ac0272807dfc8e09608cc
# 1          Site engineer 1985-06-20  10c4b3fb33137f77d48beecdb3bd34e0
#
#        unix_time  merch_lat merch_long  is_fraud  trans_id
# 0  1325537678000  35.803902 -86.511188         0      3339
# 1  1325537723000  32.997271 -97.267328         0      3340
#
# [2 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319 entries, 0 to 318
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   trans_date_trans_time  319 non-null    datetime64[ns]
#  1   cc_num                 319 non-null    int64
#  2   merchant               319 non-null    object
#  3   category               319 non-null    object
#  4   amt                    319 non-null    float64
#  5   first                  319 non-null    object
#  6   last                   319 non-null    object
#  7   gender                 319 non-null    object
#  8   street                 319 non-null    object
#  9   city                   319 non-null    object
#  10  state                  319 non-null    object
#  11  zipcode                319 non-null    object
#  12  latitude               319 non-null    float64
#  13  longitude              319 non-null    float64
#  14  city_pop               319 non-null    int64
#  15  job                    319 non-null    object
#  16  dob                    319 non-null    datetime64[ns]
#  17  trans_num              319 non-null    object
#  18  unix_time              319 non-null    int64
#  19  merch_lat              319 non-null    float64
#  20  merch_long             319 non-null    float64
#  21  is_fraud               319 non-null    int64
#  22  trans_id               319 non-null    int64
# dtypes: datetime64[ns](2), float64(5), int64(5), object(11)
# memory usage: 57.4+ KB

# %%
con = ibis.pandas.connect()
tm = con.create_table("transaction", df)

# %%
def create_window_spec(group_by, order_by, interval_in_minutes):
    return ibis.window(
        group_by=group_by,
        order_by=order_by,
        range=(-ibis.interval(minutes=interval_in_minutes), 0),
    )

time_windows_in_minutes = [5, 60, 60*24, 60*24*30]

user_window_specs = [
    {
        "agg_level": "user", 
        "agg_col": "amt", 
        "agg_stats": ["sum", "min", "max", "median"],
        "group_by": [tm.first, tm.last, tm.dob], 
        "order_by": tm.trans_date_trans_time, 
        "windows": time_windows_in_minutes # units: minutes
    },
    {
        "agg_level": "credict_card", 
        "agg_col": "amt", 
        "agg_stats": ["sum", "min", "max", "median"],
        "group_by": [tm.cc_num], 
        "order_by": tm.trans_date_trans_time, 
        "windows": time_windows_in_minutes # units: minutes
    },
]

context_window_specs = [
    {
        "agg_level": "zipcode", 
        "agg_col": "amt", 
        "agg_stats": ["sum", "min", "max", "median"],
        "group_by": [tm.zipcode], 
        "order_by": tm.trans_date_trans_time, 
        "windows": time_windows_in_minutes # units: minutes
    },
    {
        "agg_level": "merchant", 
        "agg_col": "amt", 
        "agg_stats": ["sum", "min", "max", "median"],
        "group_by": [tm.merchant], 
        "order_by": tm.trans_date_trans_time, 
        "windows": time_windows_in_minutes # units: minutes
    },
    {
        "agg_level": "category", 
        "agg_col": "amt", 
        "agg_stats": ["sum", "min", "max", "median"],
        "group_by": [tm.category], 
        "order_by": tm.trans_date_trans_time, 
        "windows": time_windows_in_minutes # units: minutes
    },
]


user_context_window_specs = [
    {
        "agg_level": "user_category", 
        "agg_col": "amt", 
        "agg_stats": ["sum", "min", "max", "median"],
        "group_by": [tm.first, tm.last, tm.dob, tm.category], 
        "order_by": tm.trans_date_trans_time, 
        "windows": time_windows_in_minutes # units: minutes
    },
    {
        "agg_level": "user_merchant", 
        "agg_col": "amt", 
        "agg_stats": ["sum", "min", "max", "median"],
        "group_by": [tm.first, tm.last, tm.dob, tm.merchant], 
        "order_by": tm.trans_date_trans_time, 
        "windows": time_windows_in_minutes # units: minutes
    },
    {
        "agg_level": "credit_card_category", 
        "agg_col": "amt", 
        "agg_stats": ["sum", "min", "max", "median"],
        "group_by": [tm.cc_num, tm.category], 
        "order_by": tm.trans_date_trans_time, 
        "windows": time_windows_in_minutes # units: minutes
    },
    {
        "agg_level": "credit_card_merchant", 
        "agg_col": "amt", 
        "agg_stats": ["sum", "min", "max", "median"],
        "group_by": [tm.cc_num, tm.merchant], 
        "order_by": tm.trans_date_trans_time, 
        "windows": time_windows_in_minutes # units: minutes
    },
]

def generate_dataset(base_list, window_specs):

    
    # Generate aggregations dynamically using a for loop
    for spec in window_specs:
        agg_level = spec["agg_level"]
        agg_col = spec["agg_col"]
        agg_stats = spec["agg_stats"]
        group_by = spec["group_by"]
        order_by = spec["order_by"]
        windows = spec["windows"]

        for window_size in windows:
            window_spec = create_window_spec(group_by, order_by, window_size)
            for stat in agg_stats:
                base_list.append(getattr(tm[agg_col], stat)().over(window_spec).name(f"{agg_level}_{agg_col}_{stat}_last_{window_size}min"))

    # Perform the aggregation
    agged = tm[base_list]
    return agged

# %%
base_list = [tm.is_fraud, tm.amt]
dataset = generate_dataset(base_list, user_window_specs + context_window_specs + user_context_window_specs)

# %%
dataset.to_pandas()
# Out:
#      is_fraud    amt  user_amt_sum_last_5min  user_amt_min_last_5min  \
# 0           0  46.28                   46.28                   46.28
# 1           0   9.55                    9.55                    9.55
# 2           0  22.95                   22.95                   22.95
# 3           0   2.55                    2.55                    2.55
# 4           0  64.09                   64.09                   64.09
# ..        ...    ...                     ...                     ...
# 995         0   7.27                    7.27                    7.27
# 996         0  45.70                   45.70                   45.70
# 997         0  64.61                   64.61                   64.61
# 998         0  35.28                   35.28                   35.28
# 999         0  40.62                   40.62                   40.62
#
#      user_amt_max_last_5min  user_amt_median_last_5min  \
# 0                     46.28                      46.28
# 1                      9.55                       9.55
# 2                     22.95                      22.95
# 3                      2.55                       2.55
# 4                     64.09                      64.09
# ..                      ...                        ...
# 995                    7.27                       7.27
# 996                   45.70                      45.70
# 997                   64.61                      64.61
# 998                   35.28                      35.28
# 999                   40.62                      40.62
#
#      user_amt_sum_last_60min  user_amt_min_last_60min  \
# 0                      46.28                    46.28
# 1                       9.55                     9.55
# 2                      22.95                    22.95
# 3                       2.55                     2.55
# 4                      64.09                    64.09
# ..                       ...                      ...
# 995                     7.27                     7.27
# 996                    45.70                    45.70
# 997                    64.61                    64.61
# 998                    35.28                    35.28
# 999                    40.62                    40.62
#
#      user_amt_max_last_60min  user_amt_median_last_60min  ...  \
# 0                      46.28                       46.28  ...
# 1                       9.55                        9.55  ...
# 2                      22.95                       22.95  ...
# 3                       2.55                        2.55  ...
# 4                      64.09                       64.09  ...
# ..                       ...                         ...  ...
# 995                     7.27                        7.27  ...
# 996                    45.70                       45.70  ...
# 997                    64.61                       64.61  ...
# 998                    35.28                       35.28  ...
# 999                    40.62                       40.62  ...
#
#      credit_card_merchant_amt_max_last_60min  \
# 0                                      46.28
# 1                                       9.55
# 2                                      22.95
# 3                                       2.55
# 4                                      64.09
# ..                                       ...
# 995                                     7.27
# 996                                    45.70
# 997                                    64.61
# 998                                    35.28
# 999                                    40.62
#
#      credit_card_merchant_amt_median_last_60min  \
# 0                                         46.28
# 1                                          9.55
# 2                                         22.95
# 3                                          2.55
# 4                                         64.09
# ..                                          ...
# 995                                        7.27
# 996                                       45.70
# 997                                       64.61
# 998                                       35.28
# 999                                       40.62
#
#      credit_card_merchant_amt_sum_last_1440min  \
# 0                                        46.28
# 1                                         9.55
# 2                                        22.95
# 3                                         2.55
# 4                                        64.09
# ..                                         ...
# 995                                       7.27
# 996                                      45.70
# 997                                      64.61
# 998                                      35.28
# 999                                      40.62
#
#      credit_card_merchant_amt_min_last_1440min  \
# 0                                        46.28
# 1                                         9.55
# 2                                        22.95
# 3                                         2.55
# 4                                        64.09
# ..                                         ...
# 995                                       7.27
# 996                                      45.70
# 997                                      64.61
# 998                                      35.28
# 999                                      40.62
#
#      credit_card_merchant_amt_max_last_1440min  \
# 0                                        46.28
# 1                                         9.55
# 2                                        22.95
# 3                                         2.55
# 4                                        64.09
# ..                                         ...
# 995                                       7.27
# 996                                      45.70
# 997                                      64.61
# 998                                      35.28
# 999                                      40.62
#
#      credit_card_merchant_amt_median_last_1440min  \
# 0                                           46.28
# 1                                            9.55
# 2                                           22.95
# 3                                            2.55
# 4                                           64.09
# ..                                            ...
# 995                                          7.27
# 996                                         45.70
# 997                                         64.61
# 998                                         35.28
# 999                                         40.62
#
#      credit_card_merchant_amt_sum_last_43200min  \
# 0                                         46.28
# 1                                          9.55
# 2                                         22.95
# 3                                          2.55
# 4                                         64.09
# ..                                          ...
# 995                                        7.27
# 996                                       45.70
# 997                                       64.61
# 998                                       35.28
# 999                                       40.62
#
#      credit_card_merchant_amt_min_last_43200min  \
# 0                                         46.28
# 1                                          9.55
# 2                                         22.95
# 3                                          2.55
# 4                                         64.09
# ..                                          ...
# 995                                        7.27
# 996                                       45.70
# 997                                       64.61
# 998                                       35.28
# 999                                       40.62
#
#      credit_card_merchant_amt_max_last_43200min  \
# 0                                         46.28
# 1                                          9.55
# 2                                         22.95
# 3                                          2.55
# 4                                         64.09
# ..                                          ...
# 995                                        7.27
# 996                                       45.70
# 997                                       64.61
# 998                                       35.28
# 999                                       40.62
#
#      credit_card_merchant_amt_median_last_43200min
# 0                                            46.28
# 1                                             9.55
# 2                                            22.95
# 3                                             2.55
# 4                                            64.09
# ..                                             ...
# 995                                           7.27
# 996                                          45.70
# 997                                          64.61
# 998                                          35.28
# 999                                          40.62
#
# [1000 rows x 146 columns]

# %%
# 3. create sink Table
local = True
sink_schema = sch.Schema(
    {
        "cc_num": dt.int64,
        "pay_amount": dt.float64,
    }
)

sink_configs = {
    "connector": "kafka",
    "topic": "transaction_sink",
    "properties.bootstrap.servers": "localhost:9092" if local else "kafka:29092",
    "format": "json",
}

connection.create_table(
    "total_amount_by_cc_num", schema=sink_schema, tbl_properties=sink_configs
)
# Out:
# DatabaseTable: total_amount_by_cc_num
#   cc_num     int64
#   pay_amount float64

# %%
# 5. emit query result to sink table
connection.insert("total_amount_by_cc_num", agged)

# %%
if local:
    # Use the Kafka Python client to stream records from the sink topic.
    # Otherwise, the mini cluster will shut down upon script completion.
    consumer = KafkaConsumer("transaction_sink")
    for msg in zip(range(10), consumer):
        print(msg)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 5
#       1 if local:
#       2     # Use the Kafka Python client to stream records from the sink topic.
#       3     # Otherwise, the mini cluster will shut down upon script completion.
#       4     consumer = KafkaConsumer("transaction_sink")
# ----> 5     for msg in zip(range(10), consumer):
#       6         print(msg)
#
# File ~/.local/lib/python3.10/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~/.local/lib/python3.10/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~/.local/lib/python3.10/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~/.local/lib/python3.10/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~/.local/lib/python3.10/site-packages/kafka/consumer/group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File ~/.local/lib/python3.10/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~/.local/lib/python3.10/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File ~/.python/current/lib/python3.10/selectors.py:469, in EpollSelector.select(self, timeout)
#     467 ready = []
#     468 try:
# --> 469     fd_event_list = self._selector.poll(timeout, max_ev)
#     470 except InterruptedError:
#     471     return ready
#
# KeyboardInterrupt:
